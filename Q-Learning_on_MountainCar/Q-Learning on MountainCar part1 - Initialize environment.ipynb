# %%
import gym

# %%
env = gym.make("MountainCar-v0")
env.reset()

done = False

# %%
while not done:
    action = 2
    new_state, reward, done, _ = env.step(action)
    print(new_state)
    env.render()
# Out:
# [-0.57311797  0.00138026]
# [-0.57036767  0.00275029]
# [-0.56626776  0.00409991]
# [-0.56084871  0.00541905]
# [-0.55415086  0.00669785]
# [-0.54622419  0.00792667]
# [-0.53712796  0.00909623]
# [-0.52693029  0.01019767]
# [-0.51570764  0.01122266]
# [-0.50354416  0.01216348]
# [-0.490531    0.01301316]
# [-0.47676545  0.01376556]
# [-0.46234999  0.01441546]
# [-0.44739131  0.01495868]
# [-0.43199922  0.01539209]
# [-0.41628552  0.0157137 ]
# [-0.40036284  0.01592268]
# [-0.38434351  0.01601933]
# [-0.36833848  0.01600503]
# [-0.35245625  0.01588223]
# [-0.33680194  0.01565431]
# [-0.32147642  0.01532552]
# [-0.30657561  0.01490081]
# [-0.2921899   0.01438571]
# [-0.27840367  0.01378623]
# [-0.26529499  0.01310868]
# [-0.25293544  0.01235955]
# [-0.24139003  0.0115454 ]
# [-0.23071725  0.01067278]
# [-0.22096916  0.00974809]
# [-0.21219158  0.00877758]
# [-0.20442435  0.00776724]
# [-0.19770153  0.00672282]
# [-0.19205174  0.00564979]
# [-0.18749836  0.00455338]
# ...

# %%
env.close()
